# %%
import pandas as pd

# %%
df = pd.read_csv("jobs_in_data_science.csv")

# %%
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
# Muestra las últimas 5 filas
df.tail()
# Out:
#       work_year                 job_title                  job_category  \
# 9350       2021           Data Specialist  Data Management and Strategy
# 9351       2020            Data Scientist     Data Science and Research
# 9352       2021  Principal Data Scientist     Data Science and Research
# 9353       2020            Data Scientist     Data Science and Research
# 9354       2020     Business Data Analyst                 Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 9350             USD  165000         165000      United States
# 9351             USD  412000         412000      United States
# 9352             USD  151000         151000      United States
# 9353             USD  105000         105000      United States
# 9354             USD  100000         100000      United States
#
#      experience_level employment_type work_setting company_location  \
# 9350           Senior       Full-time       Remote    United States
# ...

# %%
df.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
# promedio de columna salary
promedio = df['salary'].mean()

# %%
print("El Salario promedio es:", promedio)
# Out:
# El Salario promedio es: 149927.98129342598

# %%
# Mediana de la columna 'salario'
mediana = df['salary'].median()

# %%
print("La mediana de Salario es:", mediana)
# Out:
# La mediana de Salario es: 143860.0

# %%
# valor mínimo de la columna 'Salario'
valor_minimo = df['salary'].min()

# %%
print("El valor mínimo del Salario es:", valor_minimo)
# Out:
# El valor mínimo del Salario es: 14000

# %%
# Valor máximo de la columna 'Salario'
valor_maximo = df['salary'].max()

# %%
print("El valor máximo del Salario es:", valor_maximo)
# Out:
# El valor máximo del Salario es: 450000

# %%
# Desviación estándar de la columna 'Salary'
desviacion_estandar = df['salary'].std()

# %%
print("La desviación estándar del Salario es:", desviacion_estandar)
# Out:
# La desviación estándar del Salario es: 63608.83538733171

# %%
# Valor máximo y el valor mínimo de la columna 'salary'
salario_maximo = df['salary'].max()
salario_minimo = df['salary'].min()

# Calcular el rango salarial
rango_salarial = salario_maximo - salario_minimo

# Resultado Rango Salarial
print("El rango salarial es:", rango_salarial)
# Out:
# El rango salarial es: 436000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el archivo CSV
df = pd.read_csv("jobs_in_data_science.csv")

# Seleccionar la columna para crear el heatmap
columna = df['salary']

# Convertir la columna en una matriz 2D (necesario para heatmap)
# Usamos .values para convertirla en un array de numpy
columna_2d = columna.values.reshape(-1, 1)

# Crear el heatmap
sns.heatmap(columna_2d, cmap="YlGnBu", annot=True)

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#       5 # Cargar el archivo CSV
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# archivo CSV
df = pd.read_csv("jobs_in_data_science.csv")

# Columna para crear el heatmap
columna = df['salary']

# Convertir la columna en una matriz 2D 
# Usamos .values para convertirla en un array de numpy
columna_2d = columna.values.reshape(-1, 1)

# Crear el heatmap
sns.heatmap(columna_2d, cmap="YlGnBu", annot=True)

# Para mostrar el gráfico
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# archivo CSV
df = pd.read_csv("jobs_in_data_science.csv")

# Columna para crear el heatmap
columna = df['salary_in_usd']

# Convertir la columna en una matriz 2D 
# Usamos .values para convertirla en un array de numpy
columna_2d = columna.values.reshape(-1, 1)

# Crear el heatmap
sns.heatmap(columna_2d, cmap="YlGnBu", annot=True)

# Para mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("jobs_in_data_science.csv")
columna1 = "salary"  # columna salary
columna2 = "salary_in_usd"  # columna salary_in_usd

salarios1 = df[columna1].dropna()  # Elimina valores nulos
salarios2 = df[columna2].dropna()  # Elimina valores nulos
plt.figure(figsize=(10, 6))
plt.hist(salarios1, bins=30, alpha=0.5, label="Salario", color="blue", edgecolor="black")
plt.hist(salarios2, bins=30, alpha=0.5, label="Salario en USD", color="red", edgecolor="black")

plt.xlabel("Salario")
plt.ylabel("Frecuencia")
plt.title("Distribución de Salarios")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("jobs_in_data_science.csv")
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="experience_level", y="salary_in_usd", alpha=0.7, color="blue")

plt.xlabel("Nivel de Experiencia")
plt.ylabel("Salario en USD")
plt.title("Relación entre Nivel de Experiencia y Salario")
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("jobs_in_data_science.csv")
correlation_matrix = df.corr(numeric_only=True)  # Columnas numéricas
print(correlation_matrix)
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlación")
plt.show()
# Out:
#                work_year    salary  salary_in_usd
# work_year       1.000000  0.160708       0.166003
# salary          0.160708  1.000000       0.991309
# salary_in_usd   0.166003  0.991309       1.000000

# %%
import pandas as pd
df = pd.read_csv("jobs_in_data_science.csv")
df_large_companies = df[df["company_size"] == "L"]
print(df_large_companies)
# Out:
#       work_year                       job_title                  job_category  \
# 0          2023            Data DevOps Engineer              Data Engineering
# 27         2023               Applied Scientist     Data Science and Research
# 28         2023               Applied Scientist     Data Science and Research
# 35         2023  Business Intelligence Engineer          BI and Visualization
# 36         2023  Business Intelligence Engineer          BI and Visualization
# ...         ...                             ...                           ...
# 9349       2021                   Data Engineer              Data Engineering
# 9350       2021                 Data Specialist  Data Management and Strategy
# 9351       2020                  Data Scientist     Data Science and Research
# 9352       2021        Principal Data Scientist     Data Science and Research
# 9354       2020           Business Data Analyst                 Data Analysis
#
# ...

# %%
import pandas as pd
df = pd.read_csv("jobs_in_data_science.csv")
df_large_companies = df[df["company_size"] == "S"]
print(df_large_companies)
# Out:
#       work_year                  job_title               job_category  \
# 209        2023               Data Analyst              Data Analysis
# 564        2023           Research Analyst  Data Science and Research
# 610        2023    Data Science Consultant  Data Science and Research
# 1827       2023             Data Scientist  Data Science and Research
# 2086       2020        Azure Data Engineer           Data Engineering
# ...         ...                        ...                        ...
# 9333       2020             Data Scientist  Data Science and Research
# 9334       2020             Data Scientist  Data Science and Research
# 9345       2020  Machine Learning Engineer    Machine Learning and AI
# 9346       2021   Director of Data Science  Data Science and Research
# 9353       2020             Data Scientist  Data Science and Research
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
import pandas as pd
df = pd.read_csv("jobs_in_data_science.csv")
df["salary_diff"] = df["salary"].diff()  # Diferencia entre filas consecutivas
mean_diff = df["salary_diff"].mean()  # Calcula el promedio de esas diferencias

print(f"Diferencia promedio de salario: {mean_diff:.2f}")
# Out:
# Diferencia promedio de salario: 1.28

# %%
import pandas as pd
df = pd.read_csv("jobs_in_data_science.csv")
df_work_setting = df["work_setting"].value_counts().reset_index()
df_work_setting.columns = ["work_setting", "cantidad"]
print(df_work_setting)
# Out:
#   work_setting  cantidad
# 0    In-person      5730
# 1       Remote      3434
# 2       Hybrid       191
